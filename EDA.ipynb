# %%
import pandas as pd

# %%
data=pd.read_csv("Inventory Purchases.csv")
data
# Out:
#        Customer Name  Unnamed: 1 Product ID      Product Name  \
# 0         John Smith         NaN       P101            Laptop
# 1    Michael Johnson         NaN       P102           Monitor
# 2        Emily Brown         NaN       P103          Keyboard
# 3       David Wilson         NaN       P104        Headphones
# 4        Lisa Taylor         NaN       P105        Smartphone
# 5     Sarah Anderson         NaN       P106            Tablet
# 6     Matthew Wilson         NaN       P107            Router
# 7     Jennifer Davis         NaN       P108               CPU
# 8   Jessica Martinez         NaN       P109  Wireless Earbuds
# 9     Kethciya Pearl         NaN       P110            Webcam
#
#    Opening     \nStock  Purchase/               \nStock in  \
# 0                   50                                  20
# 1                   40                                  15
# 2                   60                                  25
# ...

# %%
data.head(10)
# Out:
#        Customer Name  Unnamed: 1 Product ID      Product Name  \
# 0         John Smith         NaN       P101            Laptop
# 1    Michael Johnson         NaN       P102           Monitor
# 2        Emily Brown         NaN       P103          Keyboard
# 3       David Wilson         NaN       P104        Headphones
# 4        Lisa Taylor         NaN       P105        Smartphone
# 5     Sarah Anderson         NaN       P106            Tablet
# 6     Matthew Wilson         NaN       P107            Router
# 7     Jennifer Davis         NaN       P108               CPU
# 8   Jessica Martinez         NaN       P109  Wireless Earbuds
# 9     Kethciya Pearl         NaN       P110            Webcam
#
#    Opening     \nStock  Purchase/               \nStock in  \
# 0                   50                                  20
# 1                   40                                  15
# 2                   60                                  25
# ...

# %%
data.tail(10)
# Out:
#        Customer Name  Unnamed: 1 Product ID      Product Name  \
# 0         John Smith         NaN       P101            Laptop
# 1    Michael Johnson         NaN       P102           Monitor
# 2        Emily Brown         NaN       P103          Keyboard
# 3       David Wilson         NaN       P104        Headphones
# 4        Lisa Taylor         NaN       P105        Smartphone
# 5     Sarah Anderson         NaN       P106            Tablet
# 6     Matthew Wilson         NaN       P107            Router
# 7     Jennifer Davis         NaN       P108               CPU
# 8   Jessica Martinez         NaN       P109  Wireless Earbuds
# 9     Kethciya Pearl         NaN       P110            Webcam
#
#    Opening     \nStock  Purchase/               \nStock in  \
# 0                   50                                  20
# 1                   40                                  15
# 2                   60                                  25
# ...

# %%
data.dtypes
# Out:
#    Customer Name                                                                       object
# Unnamed: 1                                                                            float64
# Product ID                                                                             object
# Product Name                                                                           object
# Opening     \nStock                                                                     int64
# Purchase/               \nStock in                                                      int64
# Number of \nUnits Sold                                                                  int64
# Hand-In-                                                                   \nStock      int64
# Cost Price \nPer Unit                                                                   int64
# Cost Price\nTotal                                                                       int64
# dtype: object

# %%
data.isnull ()
# Out:
#       Customer Name  Unnamed: 1  Product ID  Product Name  \
# 0             False        True       False         False
# 1             False        True       False         False
# 2             False        True       False         False
# 3             False        True       False         False
# 4             False        True       False         False
# 5             False        True       False         False
# 6             False        True       False         False
# 7             False        True       False         False
# 8             False        True       False         False
# 9             False        True       False         False
#
#    Opening     \nStock  Purchase/               \nStock in  \
# 0                False                               False
# 1                False                               False
# 2                False                               False
# 3                False                               False
# ...

# %%
len(data.columns)
# Out:
# 10

# %%
len(data)
# Out:
# 10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0      Customer Name                                                                   10 non-null     object
#  1   Unnamed: 1                                                                         0 non-null      float64
#  2   Product ID                                                                         10 non-null     object
#  3   Product Name                                                                       10 non-null     object
#  4   Opening
# Stock                                                                 10 non-null     int64
#  5   Purchase/
# Stock in                                                  10 non-null     int64
# ...

# %%
data.columns
# Out:
# Index(['   Customer Name', 'Unnamed: 1', 'Product ID', 'Product Name',
#        'Opening     \nStock', 'Purchase/               \nStock in',
#        'Number of \nUnits Sold',
#        'Hand-In-                                                                   \nStock',
#        'Cost Price \nPer Unit ', 'Cost Price\nTotal '],
#       dtype='object')

# %%
data['Cost Price\nTotal '].max()
# Out:
# 72000

# %%
data['Cost Price\nTotal '].min()
# Out:
# 3000

# %%
data['Cost Price\nTotal '].mean()
# Out:
# 23729.0

# %%
data[data['Product Name']=="Smartphone"]
# Out:
#      Customer Name  Unnamed: 1 Product ID Product Name  Opening     \nStock  \
# 4      Lisa Taylor         NaN       P105   Smartphone                   70
#
#    Purchase/               \nStock in  Number of \nUnits Sold  \
# 4                                  30                      20
#
#    Hand-In-                                                                   \nStock  \
# 4                                                 80
#
#    Cost Price \nPer Unit   Cost Price\nTotal
# 4                     900               72000

# %%
total_purchases_by_product=data.groupby('Product Name')['Number of \nUnits Sold'].sum()

# %%
print(total_purchases_by_product)
# Out:
# Product Name
# CPU                  5
# Headphones           3
# Keyboard            15
# Laptop              10
# Monitor              5
# Router              12
# Smartphone          20
# Tablet               8
# Webcam              10
# Wireless Earbuds     7
# Name: Number of \nUnits Sold, dtype: int64
