# %%
1.Data Exploration

# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir("C:\\Users\\Lenovo\\Documents\\Scanned Documents")

# %%
 pd.read_csv("Inventory Purchases.csv")
# Out:
#        Customer Name Product ID      Product Name  Opening     \nStock  \
# 0         John Smith       P101            Laptop                   50
# 1    Michael Johnson       P102           Monitor                   40
# 2        Emily Brown       P103          Keyboard                   60
# 3       David Wilson       P104        Headphones                   30
# 4        Lisa Taylor       P105        Smartphone                   70
# 5     Sarah Anderson       P106            Tablet                   45
# 6     Matthew Wilson       P107            Router                   40
# 7     Jennifer Davis       P108               CPU                   25
# 8   Jessica Martinez       P109  Wireless Earbuds                   35
# 9     Kethciya Pearl       P110            Webcam                   40
#
#    Purchase               \nStock in  Number of \nUnits Sold  \
# 0                                 20                      10
# 1                                 15                       5
# ...

# %%
data.head(10)
# Out:
#        Customer Name Product ID      Product Name  Opening     \nStock  \
# 0         John Smith       P101            Laptop                   50
# 1    Michael Johnson       P102           Monitor                   40
# 2        Emily Brown       P103          Keyboard                   60
# 3       David Wilson       P104        Headphones                   30
# 4        Lisa Taylor       P105        Smartphone                   70
# 5     Sarah Anderson       P106            Tablet                   45
# 6     Matthew Wilson       P107            Router                   40
# 7     Jennifer Davis       P108               CPU                   25
# 8   Jessica Martinez       P109  Wireless Earbuds                   35
# 9     Kethciya Pearl       P110            Webcam                   40
#
#    Purchase               \nStock in  Number of \nUnits Sold  \
# 0                                 20                      10
# 1                                 15                       5
# ...

# %%
data.tail(10)
# Out:
#        Customer Name Product ID      Product Name  Opening     \nStock  \
# 0         John Smith       P101            Laptop                   50
# 1    Michael Johnson       P102           Monitor                   40
# 2        Emily Brown       P103          Keyboard                   60
# 3       David Wilson       P104        Headphones                   30
# 4        Lisa Taylor       P105        Smartphone                   70
# 5     Sarah Anderson       P106            Tablet                   45
# 6     Matthew Wilson       P107            Router                   40
# 7     Jennifer Davis       P108               CPU                   25
# 8   Jessica Martinez       P109  Wireless Earbuds                   35
# 9     Kethciya Pearl       P110            Webcam                   40
#
#    Purchase               \nStock in  Number of \nUnits Sold  \
# 0                                 20                      10
# 1                                 15                       5
# ...

# %%
data.dtypes
# Out:
#    Customer Name                                                                      object
# Product ID                                                                            object
# Product Name                                                                          object
# Opening     \nStock                                                                    int64
# Purchase               \nStock in                                                      int64
# Number of \nUnits Sold                                                                 int64
# Hand-In-                                                                   \nStock     int64
# Cost Price \nPer Unit                                                                  int64
# Cost Price\nTotal                                                                      int64
# dtype: object

# %%
data.isnull ()
# Out:
#       Customer Name  Product ID  Product Name  Opening     \nStock  \
# 0             False       False         False                False
# 1             False       False         False                False
# 2             False       False         False                False
# 3             False       False         False                False
# 4             False       False         False                False
# 5             False       False         False                False
# 6             False       False         False                False
# 7             False       False         False                False
# 8             False       False         False                False
# 9             False       False         False                False
#
#    Purchase               \nStock in  Number of \nUnits Sold  \
# 0                              False                   False
# 1                              False                   False
# ...

# %%
len(data)
# Out:
# 10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0      Customer Name                                                                   10 non-null     object
#  1   Product ID                                                                         10 non-null     object
#  2   Product Name                                                                       10 non-null     object
#  3   Opening
# Stock                                                                 10 non-null     int64
#  4   Purchase
# Stock in                                                   10 non-null     int64
#  5   Number of
# Units Sold                                                              10 non-null     int64
# ...

# %%
data.columns
# Out:
# Index(['   Customer Name', 'Product ID', 'Product Name', 'Opening     \nStock',
#        'Purchase               \nStock in', 'Number of \nUnits Sold',
#        'Hand-In-                                                                   \nStock',
#        'Cost Price \nPer Unit ', 'Cost Price\nTotal '],
#       dtype='object')

# %%
data['Cost Price\nTotal '].max()
# Out:
# 72000

# %%
data['Cost Price\nTotal '].min()
# Out:
# 3000

# %%
data['Cost Price\nTotal '].mean()
# Out:
# 23729.0

# %%
data[data['Product Name']=="Smartphone"]
# Out:
#      Customer Name Product ID Product Name  Opening     \nStock  \
# 4      Lisa Taylor       P105   Smartphone                   70
#
#    Purchase               \nStock in  Number of \nUnits Sold  \
# 4                                 30                      20
#
#    Hand-In-                                                                   \nStock  \
# 4                                                 80
#
#    Cost Price \nPer Unit   Cost Price\nTotal
# 4                     900               72000

# %%
2.Data Cleaning

# %%
data.describe()
# Out:
#        Opening     \nStock  Purchase               \nStock in  \
# count            10.000000                          10.000000
# mean             43.500000                          18.700000
# std              13.550318                           6.056218
# min              25.000000                          10.000000
# 25%              36.250000                          15.000000
# 50%              40.000000                          19.000000
# 75%              48.750000                          21.500000
# max              70.000000                          30.000000
#
#        Number of \nUnits Sold  \
# count               10.000000
# mean                 9.500000
# std                  5.147815
# min                  3.000000
# 25%                  5.500000
# 50%                  9.000000
# 75%                 11.500000
# max                 20.000000
#
#        Hand-In-                                                                   \nStock  \
# ...

# %%
data.shape
# Out:
# (10, 9)

# %%
data.nunique()
# Out:
#    Customer Name                                                                      10
# Product ID                                                                            10
# Product Name                                                                          10
# Opening     \nStock                                                                    8
# Purchase               \nStock in                                                      8
# Number of \nUnits Sold                                                                 8
# Hand-In-                                                                   \nStock     9
# Cost Price \nPer Unit                                                                 10
# Cost Price\nTotal                                                                      9
# dtype: int64

# %%
data['Product Name'].unique()
# Out:
# array(['Laptop', 'Monitor', 'Keyboard', 'Headphones', 'Smartphone',
#        'Tablet', 'Router', 'CPU', 'Wireless Earbuds', 'Webcam'],
#       dtype=object)

# %%
data.isnull().sum()
# Out:
#    Customer Name                                                                      0
# Product ID                                                                            0
# Product Name                                                                          0
# Opening     \nStock                                                                   0
# Purchase               \nStock in                                                     0
# Number of \nUnits Sold                                                                0
# Hand-In-                                                                   \nStock    0
# Cost Price \nPer Unit                                                                 0
# Cost Price\nTotal                                                                     0
# dtype: int64

# %%
missing_inventory=["Number of \nUnits Sold","Number of \nUnits Sold"]

# %%
data.isnull().sum()
# Out:
#    Customer Name                                                                      0
# Product ID                                                                            0
# Product Name                                                                          0
# Opening     \nStock                                                                   0
# Purchase               \nStock in                                                     0
# Number of \nUnits Sold                                                                0
# Hand-In-                                                                   \nStock    0
# Cost Price \nPer Unit                                                                 0
# Cost Price\nTotal                                                                     0
# dtype: int64

# %%
data.isnull().any()
# Out:
#    Customer Name                                                                      False
# Product ID                                                                            False
# Product Name                                                                          False
# Opening     \nStock                                                                   False
# Purchase               \nStock in                                                     False
# Number of \nUnits Sold                                                                False
# Hand-In-                                                                   \nStock    False
# Cost Price \nPer Unit                                                                 False
# Cost Price\nTotal                                                                     False
# dtype: bool

# %%
data.drop_duplicates(subset='Product Name', keep='last')
# Out:
#        Customer Name Product ID      Product Name  Opening     \nStock  \
# 0         John Smith       P101            Laptop                   50
# 1    Michael Johnson       P102           Monitor                   40
# 2        Emily Brown       P103          Keyboard                   60
# 3       David Wilson       P104        Headphones                   30
# 4        Lisa Taylor       P105        Smartphone                   70
# 5     Sarah Anderson       P106            Tablet                   45
# 6     Matthew Wilson       P107            Router                   40
# 7     Jennifer Davis       P108               CPU                   25
# 8   Jessica Martinez       P109  Wireless Earbuds                   35
# 9     Kethciya Pearl       P110            Webcam                   40
#
#    Purchase               \nStock in  Number of \nUnits Sold  \
# 0                                 20                      10
# 1                                 15                       5
# ...
